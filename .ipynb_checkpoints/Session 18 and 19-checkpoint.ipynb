# %%
# CARD GAME PROJECT

# %%
# 52 cards in a deck
# 4 suits = Diamonds, clubs, hearts, spade
# in each suit we have 13 cards each


# PATTE PE PATTA- card on top of other card

# %%
'''
1. This game involves two players and initialy each player is given 26 cards each.
2. They have to put there top card on the table turn wise
3. If the card they are going to put on table matchs with the already top card on the table
MATCH condition - Two cards match if they have same suit OR if they have same rank
4. Player wins that chance and he take all the cards on the table and add all those cards to the end of the deck of cards he
already have.
5. This way game runs until one of the player run out of cards
6. The player that run out of cards losses and other player wins the game!!!!!
'''
# Out:
# '\n1. This game involves two players and initialy each player is given 26 cards each.\n2. They have to put there top card on the table turn wise\n3. If the card they are going to put on table matchs with the already top card on the table\nMATCH condition - Two cards match if they have same suit OR if they have same rank\n4. Player wins that chance and he take all the cards on the table and add all those cards to the end of the deck of cards he\nalready have.\n5. This way game runs until one of the player run out of cards\n6. The player that run out of cards losses and other player wins the game!!!!!\n'

# %%
import random

suits = ('Hearts','Diamonds','Clubs','Spades')

ranks = ('Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace')

values = {'Two':2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':10,'Queen':10,'King':10,'Ace':11}

# %%
#For this we need to build for classes

#1 . Card class - Hold the information about the card

#2 . Deck class - Hold the information about the complete set of 52 cards

#3 . Player class - Hold the information about the cards the player are having

#4 . Table class - Holds the information about the cards on table.

# %%
# CARD CLASS

class Card:

    def __init__(self,suit,rank):
        self.suit = suit           # identity of a card
        self.rank = rank

    def __str__(self):
        return self.rank + ' of ' + self.suit     #returns a string defining the card

# %%
a = Card('Clubs','Ten')
print(a)
# Out:
# Ten of Clubs

# %%
# DECK CLASS

class Deck:
    
    def __init__(self):
        self.deck = []  # start with an empty list
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))  # build Card objects and add them to the list
    
    def __str__(self):
        deck_comp = ''  # start with an empty string
        for card in self.deck:
            deck_comp += '\n '+card.__str__() # add each Card object's print string
        return 'The deck has:' + deck_comp

    def shuffle(self):           # Shuffles the 52 cards
        random.shuffle(self.deck)          
    def __len__(self):
        return len(self.deck)

# %%
d = Deck()
d.shuffle()

# %%
print(d)
# Out:
# The deck has:
#  Five of Spades
#  Ace of Spades
#  Queen of Hearts
#  Ten of Clubs
#  Jack of Diamonds
#  Ten of Diamonds
#  Eight of Spades
#  Eight of Diamonds
#  Three of Spades
#  Three of Clubs
#  Five of Clubs
#  Ten of Hearts
#  King of Spades
#  Queen of Diamonds
#  Four of Spades
#  Two of Hearts
#  King of Diamonds
#  King of Hearts
#  Two of Spades
#  Four of Hearts
#  Three of Hearts
#  Queen of Clubs
#  Two of Clubs
#  Six of Clubs
#  King of Clubs
#  Seven of Clubs
#  Six of Diamonds
#  Ace of Clubs
#  Five of Diamonds
#  Ace of Diamonds
#  Seven of Spades
#  Nine of Diamonds
#  Three of Diamonds
#  Five of Hearts
#  Six of Spades
#  Nine of Spades
#  Eight of Hearts
#  Eight of Clubs
#  Nine of Clubs
#  Nine of Hearts
#  Ten of Spades
#  Four of Diamonds
#  Two of Diamonds
#  Jack of Spades
#  Four of Clubs
#  Seven of Hearts
#  Ace of Hearts
#  Jack of Clubs
#  Seven of Diamonds
#  Jack of Hearts
#  Queen of Spades
#  Six of Hearts

# %%
# PLAYER CLASS -  Hold the information about the cards the player are having


class Player:
    def __init__(self,name):
        self.cards = []
        self.name = name
    def add(self , new_cards):          # Add the cards from the table after the persor wins
        self.cards.extend(new_cards)  
        
    def move(self):                     #Puts one card on the table
        return self.cards.pop(0)
    
    def __str__(self):
        ans =''
        for cards in self.cards:
            ans += '\n' + cards.__str__()
        return  self.name +" has the following cards:" +ans
    def __len__(self):
        return len(self.cards)

# %%
# TABLE CLASS Holds the information about the cards on table.

class Table:
    
    def __init__(self):
        self.cards = []
        
    def add(self,new_cards):
        self.cards.append(new_cards)
        
        
    def remove(self):
        self.cards = []
        
        
    def __str__(self):
        ans = ''
        
        for cards in self.cards:
            ans += '\n'+cards.__str__()
            
        return 'Table has these following cards ' + ans
    
        
    def __len__(self):
        return len(self.cards)

# %%
# This function take the input names of the players


def player_name():
    user_1 = input('Hi please enter your name')
    print('Hi ',user_1)
    user_2 = input('Hi enter your name')
    print('Hello ', user_2)
    
    return(user_1,user_2)

# %%
# Intialize the deck

deck = Deck()
deck.shuffle()

print(len(deck))
# Out:
# 52

# %%
# enter the information of new players

name_1,name_2 = player_name()
user_1 = Player(name_1)
user_2 = Player(name_2)
# Out:
# Hi please enter your nameAreeb
# Hi  Areeb
# Hi enter your nameHimanshu
# Hello  Himanshu

# %%
user_1.add(deck.deck[0:26])
user_2.add(deck.deck[26:52])

# %%
print(user_1)
# Out:
# Areeb has the following cards:
# Queen of Clubs
# Three of Diamonds
# Seven of Diamonds
# Eight of Diamonds
# King of Diamonds
# Nine of Spades
# Two of Diamonds
# Two of Spades
# Nine of Hearts
# Ten of Spades
# Seven of Clubs
# Queen of Diamonds
# Seven of Spades
# Four of Diamonds
# Three of Clubs
# Ten of Clubs
# King of Spades
# Eight of Clubs
# Nine of Clubs
# King of Hearts
# Ten of Diamonds
# Queen of Hearts
# Jack of Diamonds
# Six of Hearts
# Ace of Clubs
# Three of Hearts

# %%
# initialized the table
table = Table()

# %%
player = 1

while True:
    print('No of cards with',user_1.name,'are',len(user_1))
    print('No of cards with',user_2.name,'are',len(user_2))
    print('No of cards on the Table', len(table))
    
    print('\n')
    
    if player == 1:
        
    
        card = user_1.move()
        print(user_1.name,'Please press enter to move a chance, you have a card',card.__str__(),'\n')
        a = input('Press enter')
        print('Top cards on the table are','\n')
        table.add(card)
        
        print(table.cards[-1])
        
        if len(table)>1:
            print(table.cards[-2])
            
        if len(table)>1:
            if table.cards[-1].suit == table.cards[-2].suit or table.cards[-1].rank == table.cards[-2].rank:
                print('Wooho top two cards match', user_1.name, 'wins this move','\n')
                user_1.add(table.cards[::-1])
                table.remove()
                
        
        player=2
        
        
    else:
        
        card = user_2.move()
        print(user_2.name,'Please press enter to move a chance, you have a card',card.__str__(),'\n')
        a = input('Press enter')
        print('Top cards on the table are','\n')
        table.add(card)
        
        print(table.cards[-1])
        
        if len(table)>1:
            print(table.cards[-2])
            
        if len(table)>1:
            if table.cards[-1].suit == table.cards[-2].suit or table.cards[-1].rank == table.cards[-2].rank:
                print('Wooho top two cards match', user_2.name, 'wins this move','\n')
                user_2.add(table.cards[::-1])
                table.remove()
                
        
        player=1
        
        
    
    print('\n')
    if len(user_1) == 0:
        print('Congrats', user_2.name, 'Won')
        break
        
    if len(user_2)==0:
        print('Congrats',user_1.name, 'Won')
        break
# Out:
# No of cards with Areeb are 26
# No of cards with Himanshu are 26
# No of cards on the Table 0
#
#
# Areeb Please press enter to move a chance, you have a card Queen of Clubs
#
# Press enter
# Top cards on the table are
#
# Queen of Clubs
#
#
# No of cards with Areeb are 25
# No of cards with Himanshu are 26
# No of cards on the Table 1
#
#
# Himanshu Please press enter to move a chance, you have a card Five of Hearts
#
# Press enter
# Top cards on the table are
#
# Five of Hearts
# Queen of Clubs
#
#
# No of cards with Areeb are 25
# No of cards with Himanshu are 25
# No of cards on the Table 2
#
#
# Areeb Please press enter to move a chance, you have a card Three of Diamonds
#
# Press enter
# Top cards on the table are
#
# Three of Diamonds
# Five of Hearts
#
#
# No of cards with Areeb are 24
# No of cards with Himanshu are 25
# No of cards on the Table 3
#
#
# Himanshu Please press enter to move a chance, you have a card Six of Clubs
#
# Press enter
# Top cards on the table are
#
# Six of Clubs
# Three of Diamonds
#
#
# No of cards with Areeb are 24
# No of cards with Himanshu are 24
# No of cards on the Table 4
#
#
# Areeb Please press enter to move a chance, you have a card Seven of Diamonds
#
# Press enter
# Top cards on the table are
#
# Seven of Diamonds
# Six of Clubs
#
#
# No of cards with Areeb are 23
# No of cards with Himanshu are 24
# No of cards on the Table 5
#
#
# Himanshu Please press enter to move a chance, you have a card Six of Spades
#
# Press enter
# Top cards on the table are
#
# Six of Spades
# Seven of Diamonds
#
#
# No of cards with Areeb are 23
# No of cards with Himanshu are 23
# No of cards on the Table 6
#
#
# Areeb Please press enter to move a chance, you have a card Eight of Diamonds
#
# Press enter
# Top cards on the table are
#
# Eight of Diamonds
# Six of Spades
#
#
# No of cards with Areeb are 22
# No of cards with Himanshu are 23
# No of cards on the Table 7
#
#
# Himanshu Please press enter to move a chance, you have a card Ace of Spades
#
# Press enter
# Top cards on the table are
#
# Ace of Spades
# Eight of Diamonds
#
#
# No of cards with Areeb are 22
# No of cards with Himanshu are 22
# No of cards on the Table 8
#
#
# Areeb Please press enter to move a chance, you have a card King of Diamonds
#
# Press enter
# Top cards on the table are
#
# King of Diamonds
# Ace of Spades
#
#
# No of cards with Areeb are 21
# No of cards with Himanshu are 22
# No of cards on the Table 9
#
#
# Himanshu Please press enter to move a chance, you have a card Two of Clubs
#
# Press enter
# Top cards on the table are
#
# Two of Clubs
# King of Diamonds
#
#
# No of cards with Areeb are 21
# No of cards with Himanshu are 21
# No of cards on the Table 10
#
#
# Areeb Please press enter to move a chance, you have a card Nine of Spades
#
# Press enter
# Top cards on the table are
#
# Nine of Spades
# Two of Clubs
#
#
# No of cards with Areeb are 20
# No of cards with Himanshu are 21
# No of cards on the Table 11
#
#
# Himanshu Please press enter to move a chance, you have a card Six of Diamonds
#
# Press enter
# Top cards on the table are
#
# Six of Diamonds
# Nine of Spades
#
#
# No of cards with Areeb are 20
# No of cards with Himanshu are 20
# No of cards on the Table 12
#
#
# Areeb Please press enter to move a chance, you have a card Two of Diamonds
#
# Press enter
# Top cards on the table are
#
# Two of Diamonds
# Six of Diamonds
# Wooho top two cards match Areeb wins this move
#
#
#
# No of cards with Areeb are 32
# No of cards with Himanshu are 20
# No of cards on the Table 0
#
#
# Himanshu Please press enter to move a chance, you have a card Ace of Hearts
#
# Press enter
# Top cards on the table are
#
# Ace of Hearts
#
#
# No of cards with Areeb are 32
# No of cards with Himanshu are 19
# No of cards on the Table 1
#
#
# Areeb Please press enter to move a chance, you have a card Two of Spades
#
# Press enter
# Top cards on the table are
#
# Two of Spades
# Ace of Hearts
#
#
# No of cards with Areeb are 31
# No of cards with Himanshu are 19
# No of cards on the Table 2
#
#
# Himanshu Please press enter to move a chance, you have a card King of Clubs
#
# Press enter
# Top cards on the table are
#
# King of Clubs
# Two of Spades
#
#
# No of cards with Areeb are 31
# No of cards with Himanshu are 18
# No of cards on the Table 3
#
#
# Areeb Please press enter to move a chance, you have a card Nine of Hearts
#
# Press enter
# Top cards on the table are
#
# Nine of Hearts
# King of Clubs
#
#
# No of cards with Areeb are 30
# No of cards with Himanshu are 18
# No of cards on the Table 4
#
#
# Himanshu Please press enter to move a chance, you have a card Eight of Spades
#
# Press enter
# Top cards on the table are
#
# Eight of Spades
# Nine of Hearts
#
#
# No of cards with Areeb are 30
# No of cards with Himanshu are 17
# No of cards on the Table 5
#
#
# Areeb Please press enter to move a chance, you have a card Ten of Spades
#
# Press enter
# Top cards on the table are
#
# Ten of Spades
# Eight of Spades
# Wooho top two cards match Areeb wins this move
#
#
#
# No of cards with Areeb are 35
# No of cards with Himanshu are 17
# No of cards on the Table 0
#
#
# Himanshu Please press enter to move a chance, you have a card Two of Hearts
#
# Press enter
# Top cards on the table are
#
# Two of Hearts
#
#
# No of cards with Areeb are 35
# No of cards with Himanshu are 16
# No of cards on the Table 1
#
#
# Areeb Please press enter to move a chance, you have a card Seven of Clubs
#
# Press enter
# Top cards on the table are
#
# Seven of Clubs
# Two of Hearts
#
#
# No of cards with Areeb are 34
# No of cards with Himanshu are 16
# No of cards on the Table 2
#
#
# Himanshu Please press enter to move a chance, you have a card Seven of Hearts
#
# Press enter
# Top cards on the table are
#
# Seven of Hearts
# Seven of Clubs
# Wooho top two cards match Himanshu wins this move
#
#
#
# No of cards with Areeb are 34
# No of cards with Himanshu are 18
# No of cards on the Table 0
#
#
# Areeb Please press enter to move a chance, you have a card Queen of Diamonds
#
# Press enter
# Top cards on the table are
#
# Queen of Diamonds
#
#
# No of cards with Areeb are 33
# No of cards with Himanshu are 18
# No of cards on the Table 1
#
#
# Himanshu Please press enter to move a chance, you have a card Queen of Spades
#
# Press enter
# Top cards on the table are
#
# Queen of Spades
# Queen of Diamonds
# Wooho top two cards match Himanshu wins this move
#
#
#
# No of cards with Areeb are 33
# No of cards with Himanshu are 19
# No of cards on the Table 0
#
#
# Areeb Please press enter to move a chance, you have a card Seven of Spades
#
# Press enter
# Top cards on the table are
#
# Seven of Spades
#
#
# No of cards with Areeb are 32
# No of cards with Himanshu are 19
# No of cards on the Table 1
#
#
# Himanshu Please press enter to move a chance, you have a card Three of Spades
#
# Press enter
# Top cards on the table are
#
# Three of Spades
# Seven of Spades
# Wooho top two cards match Himanshu wins this move
#
#
#
# No of cards with Areeb are 32
# No of cards with Himanshu are 20
# No of cards on the Table 0
#
#
# Areeb Please press enter to move a chance, you have a card Four of Diamonds
#
# Press enter
# Top cards on the table are
#
# Four of Diamonds
#
#
# No of cards with Areeb are 31
# No of cards with Himanshu are 20
# No of cards on the Table 1
#
#
# Himanshu Please press enter to move a chance, you have a card Ace of Diamonds
#
# Press enter
# Top cards on the table are
#
# Ace of Diamonds
# Four of Diamonds
# Wooho top two cards match Himanshu wins this move
#
#
#
# No of cards with Areeb are 31
# No of cards with Himanshu are 21
# No of cards on the Table 0
#
#
# Areeb Please press enter to move a chance, you have a card Three of Clubs
#
# Press enter
# Top cards on the table are
#
# Three of Clubs
#
#
# No of cards with Areeb are 30
# No of cards with Himanshu are 21
# No of cards on the Table 1
#
#
# Himanshu Please press enter to move a chance, you have a card Jack of Spades
#
# Press enter
# Top cards on the table are
#
# Jack of Spades
# Three of Clubs
#
#
# No of cards with Areeb are 30
# No of cards with Himanshu are 20
# No of cards on the Table 2
#
#
# Areeb Please press enter to move a chance, you have a card Ten of Clubs
#
# Press enter
# Top cards on the table are
#
# Ten of Clubs
# Jack of Spades
#
#
# No of cards with Areeb are 29
# No of cards with Himanshu are 20
# No of cards on the Table 3
#
#
# Himanshu Please press enter to move a chance, you have a card Ten of Hearts
#
# Press enter
# Top cards on the table are
#
# Ten of Hearts
# Ten of Clubs
# Wooho top two cards match Himanshu wins this move
#
#
#
# No of cards with Areeb are 29
# No of cards with Himanshu are 23
# No of cards on the Table 0
#
#
# Areeb Please press enter to move a chance, you have a card King of Spades
# Press enter
# Top cards on the table are
#
# King of Spades
#
#
# No of cards with Areeb are 28
# No of cards with Himanshu are 23
# No of cards on the Table 1
#
#
# Himanshu Please press enter to move a chance, you have a card Four of Spades
#
# Press enter
# Top cards on the table are
#
# Four of Spades
# King of Spades
# Wooho top two cards match Himanshu wins this move
#
#
#
# No of cards with Areeb are 28
# No of cards with Himanshu are 24
# No of cards on the Table 0
#
#
# Areeb Please press enter to move a chance, you have a card Eight of Clubs
#
# Press enter
# Top cards on the table are
#
# Eight of Clubs
#
#
# No of cards with Areeb are 27
# No of cards with Himanshu are 24
# No of cards on the Table 1
#
#
# Himanshu Please press enter to move a chance, you have a card Five of Spades
#
# Press enter
# Top cards on the table are
#
# Five of Spades
# Eight of Clubs
#
#
# No of cards with Areeb are 27
# No of cards with Himanshu are 23
# No of cards on the Table 2
#
#
# Areeb Please press enter to move a chance, you have a card Nine of Clubs
#
# Press enter
# Top cards on the table are
#
# Nine of Clubs
# Five of Spades
#
#
# No of cards with Areeb are 26
# No of cards with Himanshu are 23
# No of cards on the Table 3
#
#
# Himanshu Please press enter to move a chance, you have a card Four of Hearts
#
# Press enter
# Top cards on the table are
#
# Four of Hearts
# Nine of Clubs
#
#
# No of cards with Areeb are 26
# No of cards with Himanshu are 22
# No of cards on the Table 4
#
#
# Areeb Please press enter to move a chance, you have a card King of Hearts
#
# Press enter
# Top cards on the table are
#
# King of Hearts
# Four of Hearts
# Wooho top two cards match Areeb wins this move
#
#
#
# No of cards with Areeb are 30
# No of cards with Himanshu are 22
# No of cards on the Table 0
#
#
# Himanshu Please press enter to move a chance, you have a card Five of Diamonds
#
# Press enter
# Press enter
# Top cards on the table are
#
# Five of Diamonds
#
#
# No of cards with Areeb are 30
# No of cards with Himanshu are 21
# No of cards on the Table 1
#
#
# Areeb Please press enter to move a chance, you have a card Ten of Diamonds
#
# Press enter
# Top cards on the table are
#
# Ten of Diamonds
# Five of Diamonds
# Wooho top two cards match Areeb wins this move
#
#
#
# No of cards with Areeb are 31
# No of cards with Himanshu are 21
# No of cards on the Table 0
#
#
# Himanshu Please press enter to move a chance, you have a card Five of Clubs
#
# Top cards on the table are
#
# Five of Clubs
#
#
# No of cards with Areeb are 31
# No of cards with Himanshu are 20
# No of cards on the Table 1
#
#
# Areeb Please press enter to move a chance, you have a card Queen of Hearts
#
# Press enter
# Top cards on the table are
#
# Queen of Hearts
# Five of Clubs
#
#
# No of cards with Areeb are 30
# No of cards with Himanshu are 20
# No of cards on the Table 2
#
#
# Himanshu Please press enter to move a chance, you have a card Four of Clubs
#
# Press enter
# Top cards on the table are
#
# Four of Clubs
# Queen of Hearts
#
#
# No of cards with Areeb are 30
# No of cards with Himanshu are 19
# No of cards on the Table 3
#
#
# Areeb Please press enter to move a chance, you have a card Jack of Diamonds
#
# Press enter
# Top cards on the table are
#
# Jack of Diamonds
# Four of Clubs
#
#
# No of cards with Areeb are 29
# No of cards with Himanshu are 19
# No of cards on the Table 4
#
#
# Himanshu Please press enter to move a chance, you have a card Eight of Hearts
#
# Press enter
# Top cards on the table are
#
# Eight of Hearts
# Jack of Diamonds
#
#
# No of cards with Areeb are 29
# No of cards with Himanshu are 18
# No of cards on the Table 5
#
#
# Areeb Please press enter to move a chance, you have a card Six of Hearts
#
# Press enter
# Top cards on the table are
#
# Six of Hearts
# Eight of Hearts
# Wooho top two cards match Areeb wins this move
#
#
#
# No of cards with Areeb are 34
# No of cards with Himanshu are 18
# No of cards on the Table 0
#
#
# Himanshu Please press enter to move a chance, you have a card Nine of Diamonds
#
# Press enter
# Top cards on the table are
#
# Nine of Diamonds
#
#
# No of cards with Areeb are 34
# No of cards with Himanshu are 17
# No of cards on the Table 1
#
#
# Areeb Please press enter to move a chance, you have a card Ace of Clubs
#
# Press enter
# Top cards on the table are
#
# Ace of Clubs
# Nine of Diamonds
#
#
# No of cards with Areeb are 33
# No of cards with Himanshu are 17
# No of cards on the Table 2
#
#
# Himanshu Please press enter to move a chance, you have a card Jack of Clubs
#
# Press enter
# Top cards on the table are
#
# Jack of Clubs
# Ace of Clubs
# Wooho top two cards match Himanshu wins this move
#
#
#
# No of cards with Areeb are 33
# No of cards with Himanshu are 19
# No of cards on the Table 0
#
#
# Areeb Please press enter to move a chance, you have a card Three of Hearts
#
# Press enter
# Top cards on the table are
#
# Three of Hearts
#
#
# No of cards with Areeb are 32
# No of cards with Himanshu are 19
# No of cards on the Table 1
#
#
# Himanshu Please press enter to move a chance, you have a card Jack of Hearts
#
# Press enter
# Top cards on the table are
#
# Jack of Hearts
# Three of Hearts
# Wooho top two cards match Himanshu wins this move
#
#
#
# No of cards with Areeb are 32
# No of cards with Himanshu are 20
# No of cards on the Table 0
#
#
# Areeb Please press enter to move a chance, you have a card Two of Diamonds
#
# Press enter
# Top cards on the table are
#
# Two of Diamonds
#
#
# No of cards with Areeb are 31
# No of cards with Himanshu are 20
# No of cards on the Table 1
#
#
# Himanshu Please press enter to move a chance, you have a card Seven of Hearts
